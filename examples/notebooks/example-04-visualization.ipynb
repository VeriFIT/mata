# %%
import libmata as mata
from libmata.nfa.nfa import *
from libmata.parser import *
import libmata.plotting

# %% [markdown]
# ## Auxiliary Functions

# %%
def distance_from(aut: Nfa) -> dict[int,int]:
    queue = []
    dist = dict()
    for q in aut.initial_states:
        dist[q] = 0
        queue.append(q)

    while len(queue) != 0:
        act = queue.pop(0)
        for trans in aut.get_trans_from_state_as_sequence(act):
            if not trans.target in dist:
                dist[trans.target] = dist[act] + 1
                queue.append(trans.target)
    return dist

def hexa_heat(minimum, maximum, value):
    ratio = 2 * (value-float(minimum)) / float((maximum - minimum))
    b = int(max(0, 255 * (1 - ratio)))
    r = int(max(0, 255 * (ratio - 1)))
    g = 255 - b - r
    return "#{:02x}{:02x}{:02x}".format(r, g, b)

# %% [markdown]
# Creation of example automata

# %%
libmata.plotting.store()['alphabet'] = mata.alphabets.OnTheFlyAlphabet.from_symbol_map({"0":0, "1":1})
lhs = divisible_by(4)
lhs.label = "aut1"
rhs = divisible_by(3)
rhs.label = "aut2"
result = concatenate(lhs, rhs)
result.label = "aut1.aut2"

# %% [markdown]
# ## Conditional State/Transition Formatting

# %%
e_h = [
    (lambda aut, edge: edge.symbol == 1, {'color': 'grey'}),
    (lambda aut, edge: edge.symbol == 0, {'style': 'dashed', 'color': 'grey'})
]
n_h = [
    (lambda aut, state: state in aut.final_states, {'color': 'red', 'fillcolor': 'red'}),
    (lambda aut, state: state in aut.initial_states, {'color': 'green', 'fillcolor': 'green'}),
]
libmata.plotting.plot(lhs, rhs, result, node_highlight=n_h, edge_highlight=e_h)
# Out:
# <div style='vertical-align:text-top;display:inline-block;'><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (0)
#  -->
# <!-- Title: dot Pages: 1 -->
# <svg width="90pt" height="431pt"
#  viewBox="0.00 0.00 90.35 430.75" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 426.75)">
# <title>dot</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-426.75 86.35,-426.75 86.35,4 -4,4"/>
# <text text-anchor="middle" x="41.17" y="-405.45" font-family="Helvetica,sans-Serif" font-size="14.00">aut1</text>
# <!-- q0 -->
# <g id="node1" class="node">
# <title>q0</title>
# </g>
# <!-- 0 -->
# <g id="node2" class="node">
# <title>0</title>
# <ellipse fill="green" stroke="green" stroke-width="1.5" cx="42.8" cy="-315.2" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="42.8" y="-310.93" font-family="Courier,monospace" font-weight="bold" font-size="12.00">0</text>
# </g>
# <!-- q0&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>q0&#45;&gt;0</title>
# <path fill="none" stroke="midnightblue" stroke-width="1.5" d="M42.8,-363.24C42.8,-355.67 42.8,-346.63 42.8,-338.5"/>
# <polygon fill="midnightblue" stroke="midnightblue" stroke-width="1.5" points="46.3,-338.74 42.8,-328.74 39.3,-338.74 46.3,-338.74"/>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="grey" stroke-width="1.5" stroke-dasharray="5,2" d="M52.84,-319.72C61.9,-321.91 71.6,-320.41 71.6,-315.2 71.6,-312.43 68.86,-310.71 64.94,-310.04"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="64.9,-306.53 55.1,-310.56 65.28,-313.52 64.9,-306.53"/>
# <text text-anchor="middle" x="74.97" y="-310.15" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node3" class="node">
# <title>1</title>
# <ellipse fill="lightsteelblue" stroke="darkblue" stroke-width="1.5" cx="42.8" cy="-241.1" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="42.8" y="-236.83" font-family="Courier,monospace" font-weight="bold" font-size="12.00">1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="grey" stroke-width="1.5" d="M42.8,-304.17C42.8,-293.84 42.8,-277.41 42.8,-264.04"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="46.3,-264.31 42.8,-254.31 39.3,-264.31 46.3,-264.31"/>
# <text text-anchor="middle" x="46.17" y="-273.1" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g id="edge4" class="edge">
# <title>1&#45;&gt;1</title>
# <path fill="none" stroke="grey" stroke-width="1.5" stroke-dasharray="5,2" d="M52.54,-246.72C61.68,-249.63 71.6,-247.76 71.6,-241.1 71.6,-237.46 68.63,-235.25 64.45,-234.47"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="64.47,-230.96 54.8,-235.29 65.06,-237.93 64.47,-230.96"/>
# <text text-anchor="middle" x="74.97" y="-236.05" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 2 -->
# <g id="node4" class="node">
# <title>2</title>
# <ellipse fill="lightsteelblue" stroke="darkblue" stroke-width="1.5" cx="10.8" cy="-167" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="10.8" y="-162.72" font-family="Courier,monospace" font-weight="bold" font-size="12.00">2</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge5" class="edge">
# <title>1&#45;&gt;2</title>
# <path fill="none" stroke="grey" stroke-width="1.5" d="M38.62,-230.67C33.85,-219.93 25.91,-202.05 19.74,-188.13"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="23.06,-187 15.8,-179.28 16.66,-189.84 23.06,-187"/>
# <text text-anchor="middle" x="33.17" y="-199" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 2&#45;&gt;2 -->
# <g id="edge6" class="edge">
# <title>2&#45;&gt;2</title>
# <path fill="none" stroke="grey" stroke-width="1.5" stroke-dasharray="5,2" d="M20.54,-172.62C29.68,-175.53 39.6,-173.66 39.6,-167 39.6,-163.36 36.63,-161.15 32.45,-160.37"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="32.47,-156.86 22.8,-161.19 33.06,-163.83 32.47,-156.86"/>
# <text text-anchor="middle" x="42.97" y="-161.95" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 3 -->
# <g id="node5" class="node">
# <title>3</title>
# <ellipse fill="lightsteelblue" stroke="darkblue" stroke-width="1.5" cx="10.8" cy="-92.9" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="10.8" y="-88.62" font-family="Courier,monospace" font-weight="bold" font-size="12.00">3</text>
# </g>
# <!-- 2&#45;&gt;3 -->
# <g id="edge7" class="edge">
# <title>2&#45;&gt;3</title>
# <path fill="none" stroke="grey" stroke-width="1.5" d="M10.8,-155.97C10.8,-145.64 10.8,-129.21 10.8,-115.84"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="14.3,-116.11 10.8,-106.11 7.3,-116.11 14.3,-116.11"/>
# <text text-anchor="middle" x="14.17" y="-124.9" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 3&#45;&gt;3 -->
# <g id="edge8" class="edge">
# <title>3&#45;&gt;3</title>
# <path fill="none" stroke="grey" stroke-width="1.5" stroke-dasharray="5,2" d="M20.54,-98.52C29.68,-101.43 39.6,-99.56 39.6,-92.9 39.6,-89.26 36.63,-87.05 32.45,-86.27"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="32.47,-82.76 22.8,-87.09 33.06,-89.73 32.47,-82.76"/>
# <text text-anchor="middle" x="42.97" y="-87.85" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 4 -->
# <g id="node6" class="node">
# <title>4</title>
# <ellipse fill="red" stroke="red" stroke-width="1.5" cx="42.8" cy="-14.8" rx="10.8" ry="10.8"/>
# <ellipse fill="none" stroke="red" stroke-width="1.5" cx="42.8" cy="-14.8" rx="14.8" ry="14.8"/>
# <text text-anchor="middle" x="42.8" y="-10.52" font-family="Courier,monospace" font-weight="bold" font-size="12.00">4</text>
# </g>
# <!-- 3&#45;&gt;4 -->
# <g id="edge9" class="edge">
# <title>3&#45;&gt;4</title>
# <path fill="none" stroke="grey" stroke-width="1.5" d="M14.72,-82.57C19.13,-72.09 26.46,-54.66 32.53,-40.23"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="35.7,-41.71 36.35,-31.14 29.25,-39 35.7,-41.71"/>
# <text text-anchor="middle" x="32.17" y="-50.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 4&#45;&gt;1 -->
# <g id="edge11" class="edge">
# <title>4&#45;&gt;1</title>
# <path fill="none" stroke="grey" stroke-width="1.5" d="M46.33,-29.65C49.53,-42.99 54.02,-63.77 55.8,-82.1 59.91,-124.43 60.17,-135.49 55.8,-177.8 54.38,-191.53 51.25,-206.71 48.42,-218.64"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="45.04,-217.73 46,-228.28 51.83,-219.43 45.04,-217.73"/>
# <text text-anchor="middle" x="63.17" y="-124.9" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 4&#45;&gt;4 -->
# <g id="edge10" class="edge">
# <title>4&#45;&gt;4</title>
# <path fill="none" stroke="grey" stroke-width="1.5" stroke-dasharray="5,2" d="M56.28,-21.67C65.96,-23.9 75.6,-21.61 75.6,-14.8 75.6,-11.07 72.72,-8.7 68.52,-7.68"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="68.47,-4.18 58.55,-7.89 68.62,-11.18 68.47,-4.18"/>
# <text text-anchor="middle" x="78.97" y="-9.75" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# </g>
# </svg>
# </div><div style='vertical-align:text-top;display:inline-block;'><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (0)
#  -->
# <!-- Title: dot Pages: 1 -->
# <svg width="94pt" height="357pt"
#  viewBox="0.00 0.00 94.35 356.65" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 352.65)">
# <title>dot</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-352.65 90.35,-352.65 90.35,4 -4,4"/>
# <text text-anchor="middle" x="43.17" y="-331.35" font-family="Helvetica,sans-Serif" font-size="14.00">aut2</text>
# <!-- q0 -->
# <g id="node1" class="node">
# <title>q0</title>
# </g>
# <

# %% [markdown]
# ## SCC Visualization

# %%
e_h = [
    (lambda aut, edge: edge.symbol == 1, {'color': 'grey'}),
    (lambda aut, edge: edge.symbol == 0, {'style': 'dashed', 'color': 'grey'})
]
n_h = [
    (lambda aut, state: state in aut.final_states, {'color': 'red', 'fillcolor': 'red'}),
    (lambda aut, state: state in aut.initial_states, {'color': 'green', 'fillcolor': 'green'}),
]
libmata.plotting.plot(lhs, rhs, result, with_scc=True, node_highlight=n_h, edge_highlight=e_h)
# Out:
# <div style='vertical-align:text-top;display:inline-block;'><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (0)
#  -->
# <!-- Title: dot Pages: 1 -->
# <svg width="107pt" height="463pt"
#  viewBox="0.00 0.00 107.00 462.75" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 458.75)">
# <title>dot</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-458.75 103,-458.75 103,4 -4,4"/>
# <text text-anchor="middle" x="49.5" y="-437.45" font-family="Helvetica,sans-Serif" font-size="14.00">aut1</text>
# <g id="clust1" class="cluster">
# <title>cluster_0</title>
# <polygon fill="lightgray" stroke="black" points="8,-8 8,-275.9 91,-275.9 91,-8 8,-8"/>
# </g>
# <g id="clust2" class="cluster">
# <title>cluster_1</title>
# <polygon fill="lightgray" stroke="black" points="8,-312.4 8,-423 78,-423 78,-312.4 8,-312.4"/>
# </g>
# <!-- 1 -->
# <g id="node1" class="node">
# <title>1</title>
# <ellipse fill="lightsteelblue" stroke="darkblue" stroke-width="1.5" cx="34" cy="-257.1" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="34" y="-252.83" font-family="Courier,monospace" font-weight="bold" font-size="12.00">1</text>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g id="edge4" class="edge">
# <title>1&#45;&gt;1</title>
# <path fill="none" stroke="grey" stroke-width="1.5" stroke-dasharray="5,2" d="M43.74,-262.72C52.88,-265.63 62.8,-263.76 62.8,-257.1 62.8,-253.46 59.83,-251.25 55.65,-250.47"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="55.67,-246.96 46,-251.29 56.26,-253.93 55.67,-246.96"/>
# <text text-anchor="middle" x="66.17" y="-252.05" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 2 -->
# <g id="node2" class="node">
# <title>2</title>
# <ellipse fill="lightsteelblue" stroke="darkblue" stroke-width="1.5" cx="27" cy="-183" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="27" y="-178.72" font-family="Courier,monospace" font-weight="bold" font-size="12.00">2</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge5" class="edge">
# <title>1&#45;&gt;2</title>
# <path fill="none" stroke="grey" stroke-width="1.5" d="M33.03,-246.07C32.02,-235.74 30.43,-219.31 29.13,-205.94"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="32.63,-205.81 28.18,-196.2 25.67,-206.49 32.63,-205.81"/>
# <text text-anchor="middle" x="34.38" y="-215" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 2&#45;&gt;2 -->
# <g id="edge6" class="edge">
# <title>2&#45;&gt;2</title>
# <path fill="none" stroke="grey" stroke-width="1.5" stroke-dasharray="5,2" d="M36.74,-188.62C45.88,-191.53 55.8,-189.66 55.8,-183 55.8,-179.36 52.83,-177.15 48.65,-176.37"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="48.67,-172.86 39,-177.19 49.26,-179.83 48.67,-172.86"/>
# <text text-anchor="middle" x="59.17" y="-177.95" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 3 -->
# <g id="node3" class="node">
# <title>3</title>
# <ellipse fill="lightsteelblue" stroke="darkblue" stroke-width="1.5" cx="27" cy="-108.9" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="27" y="-104.62" font-family="Courier,monospace" font-weight="bold" font-size="12.00">3</text>
# </g>
# <!-- 2&#45;&gt;3 -->
# <g id="edge7" class="edge">
# <title>2&#45;&gt;3</title>
# <path fill="none" stroke="grey" stroke-width="1.5" d="M27,-171.97C27,-161.64 27,-145.21 27,-131.84"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="30.5,-132.11 27,-122.11 23.5,-132.11 30.5,-132.11"/>
# <text text-anchor="middle" x="30.38" y="-140.9" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 3&#45;&gt;3 -->
# <g id="edge8" class="edge">
# <title>3&#45;&gt;3</title>
# <path fill="none" stroke="grey" stroke-width="1.5" stroke-dasharray="5,2" d="M36.74,-114.52C45.88,-117.43 55.8,-115.56 55.8,-108.9 55.8,-105.26 52.83,-103.05 48.65,-102.27"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="48.67,-98.76 39,-103.09 49.26,-105.73 48.67,-98.76"/>
# <text text-anchor="middle" x="59.17" y="-103.85" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 4 -->
# <g id="node4" class="node">
# <title>4</title>
# <ellipse fill="red" stroke="red" stroke-width="1.5" cx="40" cy="-30.8" rx="10.8" ry="10.8"/>
# <ellipse fill="none" stroke="red" stroke-width="1.5" cx="40" cy="-30.8" rx="14.8" ry="14.8"/>
# <text text-anchor="middle" x="40" y="-26.52" font-family="Courier,monospace" font-weight="bold" font-size="12.00">4</text>
# </g>
# <!-- 3&#45;&gt;4 -->
# <g id="edge9" class="edge">
# <title>3&#45;&gt;4</title>
# <path fill="none" stroke="grey" stroke-width="1.5" d="M28.7,-97.95C30.44,-87.77 33.21,-71.53 35.58,-57.69"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="38.98,-58.58 37.21,-48.13 32.08,-57.4 38.98,-58.58"/>
# <text text-anchor="middle" x="37.38" y="-66.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 4&#45;&gt;1 -->
# <g id="edge11" class="edge">
# <title>4&#45;&gt;1</title>
# <path fill="none" stroke="grey" stroke-width="1.5" d="M47.91,-43.89C55.8,-56.73 67.38,-77.92 72,-98.1 81.48,-139.56 83.5,-152.85 72,-193.8 67.33,-210.42 56.86,-227 48.1,-238.87"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="45.52,-236.49 42.13,-246.53 51.04,-240.79 45.52,-236.49"/>
# <text text-anchor="middle" x="82.38" y="-140.9" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 4&#45;&gt;4 -->
# <g id="edge10" class="edge">
# <title>4&#45;&gt;4</title>
# <path fill="none" stroke="grey" stroke-width="1.5" stroke-dasharray="5,2" d="M53.48,-37.67C63.16,-39.9 72.8,-37.61 72.8,-30.8 72.8,-27.07 69.92,-24.7 65.72,-23.68"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="65.67,-20.18 55.75,-23.89 65.82,-27.18 65.67,-20.18"/>
# <text text-anchor="middle" x="76.17" y="-25.75" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- q0 -->
# <g id="node5" class="node">
# <title>q0</title>
# </g>
# <!-- 0 -->
# <g id="node6" class="node">
# <title>0</title>
# <ellipse fill="green" stroke="green" stroke-width="1.5" cx="34" cy="-331.2" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="34" y="-326.93" font-family="Courier,monospace" font-weight="bold" font-size="12.00">0</text>
# </g>
# <!-- q0&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>q0&#45;&gt;0</title>
# <path fill="none" stroke="midnightblue" stroke-width="1.5" d="M40.64,-379.24C39.55,-371.58 38.26,-362.4 37.1,-354.19"/>
# <polygon fill="midnightblue" stroke="midnightblue" stroke-width="1.5" points="40.58,-353.76 35.71,-344.35 33.64,-354.74 40.58,-353.76"/>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="grey" stroke-width="1.5" d="M34,-320.17C34,-309.84 34,-293.41 34,-280.04"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="37.5,-280.31 34,-270.31 30.5,-280.31 37.5,-280.31"/>
# <text text-anchor="middle" x="37.38" y="-289.1" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="grey" stroke-width="1.5" stroke-dasharray="5,2" d="M44.04,-335.72C53.1,-337.91 62.8,-336.41 62.8,-331.2 62.8,-328.43 60.06,-326.71 56.14,-326.04"/>
# <polygon fill="grey" stroke="grey" stroke-width="1.5" points="56.1,-322.53 46.3,-326.56 56.48,-329.52 56.1,-322.53"/>
# <text text-anchor="middle" x="66.17" y="-326.15" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# </g>
# </svg>
# </div><div style='vertical-align:text-top;display:inline-block;'><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (0)
#  -->
# <!-- Title: dot Pages: 1 -->
# <svg width="130pt" height="389pt"
#  viewBox="0.00 0.00 130.00 388.65" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 384.65)">
# <ti

# %% [markdown]
# ## Example of a Heatmap

# %%
heat_map = distance_from(result)
max_heat = max(heat_map.values())
e_h = [
    (lambda aut, edge: edge.symbol == 1, {'color': 'gray'}),
    (lambda aut, edge: edge.source == edge.target, {'style': 'dashed', 'color': 'red'})
]
n_h = [
    (lambda aut, state, j=i: state == j, libmata.plotting.Style.filled(hexa_heat(0, max_heat, heat_map[i]))) for i in range(0,result.num_of_states())
]
libmata.plotting.plot(result, node_highlight=n_h, edge_highlight=e_h)
# Out:
# <div style='vertical-align:text-top;display:inline-block;'><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (0)
#  -->
# <!-- Title: dot Pages: 1 -->
# <svg width="94pt" height="727pt"
#  viewBox="0.00 0.00 94.35 727.15" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 723.15)">
# <title>dot</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-723.15 90.35,-723.15 90.35,4 -4,4"/>
# <text text-anchor="middle" x="43.17" y="-701.85" font-family="Helvetica,sans-Serif" font-size="14.00">aut1.aut2</text>
# <!-- q0 -->
# <g id="node1" class="node">
# <title>q0</title>
# </g>
# <!-- 0 -->
# <g id="node2" class="node">
# <title>0</title>
# <ellipse fill="#0000ff" stroke="darkblue" stroke-width="1.5" cx="46.8" cy="-611.6" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="46.8" y="-607.33" font-family="Courier,monospace" font-weight="bold" font-size="12.00">0</text>
# </g>
# <!-- q0&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>q0&#45;&gt;0</title>
# <path fill="none" stroke="midnightblue" stroke-width="1.5" d="M46.8,-659.64C46.8,-652.07 46.8,-643.03 46.8,-634.9"/>
# <polygon fill="midnightblue" stroke="midnightblue" stroke-width="1.5" points="50.3,-635.14 46.8,-625.14 43.3,-635.14 50.3,-635.14"/>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="red" stroke-width="1.5" stroke-dasharray="5,2" d="M56.84,-616.12C65.9,-618.31 75.6,-616.81 75.6,-611.6 75.6,-608.83 72.86,-607.11 68.94,-606.44"/>
# <polygon fill="red" stroke="red" stroke-width="1.5" points="68.9,-602.93 59.1,-606.96 69.28,-609.92 68.9,-602.93"/>
# <text text-anchor="middle" x="78.97" y="-606.55" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node3" class="node">
# <title>1</title>
# <ellipse fill="#0049b6" stroke="darkblue" stroke-width="1.5" cx="46.8" cy="-537.5" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="46.8" y="-533.23" font-family="Courier,monospace" font-weight="bold" font-size="12.00">1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="gray" stroke-width="1.5" d="M46.8,-600.57C46.8,-590.24 46.8,-573.81 46.8,-560.44"/>
# <polygon fill="gray" stroke="gray" stroke-width="1.5" points="50.3,-560.71 46.8,-550.71 43.3,-560.71 50.3,-560.71"/>
# <text text-anchor="middle" x="50.17" y="-569.5" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g id="edge4" class="edge">
# <title>1&#45;&gt;1</title>
# <path fill="none" stroke="red" stroke-width="1.5" stroke-dasharray="5,2" d="M56.54,-543.12C65.68,-546.03 75.6,-544.16 75.6,-537.5 75.6,-533.86 72.63,-531.65 68.45,-530.87"/>
# <polygon fill="red" stroke="red" stroke-width="1.5" points="68.47,-527.36 58.8,-531.69 69.06,-534.33 68.47,-527.36"/>
# <text text-anchor="middle" x="78.97" y="-532.45" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 2 -->
# <g id="node4" class="node">
# <title>2</title>
# <ellipse fill="#00926d" stroke="darkblue" stroke-width="1.5" cx="14.8" cy="-463.4" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="14.8" y="-459.13" font-family="Courier,monospace" font-weight="bold" font-size="12.00">2</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge5" class="edge">
# <title>1&#45;&gt;2</title>
# <path fill="none" stroke="gray" stroke-width="1.5" d="M42.62,-527.07C37.85,-516.33 29.91,-498.45 23.74,-484.53"/>
# <polygon fill="gray" stroke="gray" stroke-width="1.5" points="27.06,-483.4 19.8,-475.68 20.66,-486.24 27.06,-483.4"/>
# <text text-anchor="middle" x="37.17" y="-495.4" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 2&#45;&gt;2 -->
# <g id="edge6" class="edge">
# <title>2&#45;&gt;2</title>
# <path fill="none" stroke="red" stroke-width="1.5" stroke-dasharray="5,2" d="M24.54,-469.02C33.68,-471.93 43.6,-470.06 43.6,-463.4 43.6,-459.76 40.63,-457.55 36.45,-456.77"/>
# <polygon fill="red" stroke="red" stroke-width="1.5" points="36.47,-453.26 26.8,-457.59 37.06,-460.23 36.47,-453.26"/>
# <text text-anchor="middle" x="46.97" y="-458.35" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 3 -->
# <g id="node5" class="node">
# <title>3</title>
# <ellipse fill="#00db24" stroke="darkblue" stroke-width="1.5" cx="14.8" cy="-389.3" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="14.8" y="-385.03" font-family="Courier,monospace" font-weight="bold" font-size="12.00">3</text>
# </g>
# <!-- 2&#45;&gt;3 -->
# <g id="edge7" class="edge">
# <title>2&#45;&gt;3</title>
# <path fill="none" stroke="gray" stroke-width="1.5" d="M14.8,-452.37C14.8,-442.04 14.8,-425.61 14.8,-412.24"/>
# <polygon fill="gray" stroke="gray" stroke-width="1.5" points="18.3,-412.51 14.8,-402.51 11.3,-412.51 18.3,-412.51"/>
# <text text-anchor="middle" x="18.17" y="-421.3" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 3&#45;&gt;3 -->
# <g id="edge8" class="edge">
# <title>3&#45;&gt;3</title>
# <path fill="none" stroke="red" stroke-width="1.5" stroke-dasharray="5,2" d="M24.54,-394.92C33.68,-397.83 43.6,-395.96 43.6,-389.3 43.6,-385.66 40.63,-383.45 36.45,-382.67"/>
# <polygon fill="red" stroke="red" stroke-width="1.5" points="36.47,-379.16 26.8,-383.49 37.06,-386.13 36.47,-379.16"/>
# <text text-anchor="middle" x="46.97" y="-384.25" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 4 -->
# <g id="node6" class="node">
# <title>4</title>
# <ellipse fill="#24db00" stroke="darkblue" stroke-width="1.5" cx="46.8" cy="-315.2" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="46.8" y="-310.93" font-family="Courier,monospace" font-weight="bold" font-size="12.00">4</text>
# </g>
# <!-- 3&#45;&gt;4 -->
# <g id="edge9" class="edge">
# <title>3&#45;&gt;4</title>
# <path fill="none" stroke="gray" stroke-width="1.5" d="M18.98,-378.87C23.75,-368.13 31.69,-350.25 37.86,-336.33"/>
# <polygon fill="gray" stroke="gray" stroke-width="1.5" points="40.94,-338.04 41.8,-327.48 34.54,-335.2 40.94,-338.04"/>
# <text text-anchor="middle" x="37.17" y="-347.2" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 4&#45;&gt;1 -->
# <g id="edge12" class="edge">
# <title>4&#45;&gt;1</title>
# <path fill="none" stroke="gray" stroke-width="1.5" d="M49.45,-325.82C52.65,-337.97 57.85,-359.6 59.8,-378.5 64.17,-420.81 64.17,-431.89 59.8,-474.2 58.38,-487.93 55.25,-503.11 52.42,-515.04"/>
# <polygon fill="gray" stroke="gray" stroke-width="1.5" points="49.04,-514.13 50,-524.68 55.83,-515.83 49.04,-514.13"/>
# <text text-anchor="middle" x="67.17" y="-421.3" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 4&#45;&gt;4 -->
# <g id="edge10" class="edge">
# <title>4&#45;&gt;4</title>
# <path fill="none" stroke="red" stroke-width="1.5" stroke-dasharray="5,2" d="M56.54,-320.82C65.68,-323.73 75.6,-321.86 75.6,-315.2 75.6,-311.56 72.63,-309.35 68.45,-308.57"/>
# <polygon fill="red" stroke="red" stroke-width="1.5" points="68.47,-305.06 58.8,-309.39 69.06,-312.03 68.47,-305.06"/>
# <text text-anchor="middle" x="78.97" y="-310.15" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 5 -->
# <g id="node7" class="node">
# <title>5</title>
# <ellipse fill="#6d9200" stroke="darkblue" stroke-width="1.5" cx="10.8" cy="-241.1" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="10.8" y="-236.83" font-family="Courier,monospace" font-weight="bold" font-size="12.00">5</text>
# </g>
# <!-- 4&#45;&gt;5 -->
# <g id="edge11" class="edge">
# <title>4&#45;&gt;5</title>
# <path fill="none" stroke="midnightblue" stroke-width="1.5" d="M42.24,-305.07C36.86,-294.29 27.76,-276.06 20.73,-261.98"/>
# <polygon fill="midnightblue" stroke="midnightblue" stroke-width="1.5" points="24.05,-260.8 16.45,-253.42 17.79,-263.93 24.05,-260.8"/>
# <text text-anchor="middle" x="36.17" y="-273.1" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 6 -->
# <g id="node8" class="node">
# <title>6</title>
# <ellipse fill="#6d9200" stroke="darkblue" stroke-width="1.5" cx="46.8" cy="-167" rx="10.8" r

# %% [markdown]
# ## Regex Example

# %%
from libmata import nfa, alphabets, parser, plotting
aut1 = parser.from_regex('((a+b)*a)*')
aut2 = parser.from_regex('aab*')
con_aut = nfa.nfa.concatenate(aut1, aut2).trim()
# Setting correct alphabet.
plotting.store()['alphabet'] = \
    alphabets.OnTheFlyAlphabet.from_symbol_map({'a':97, 'b':98})
# Plot the concatenated and trimmed automaton.
e_h = [
    (lambda aut, e: e.symbol == 98, {'color': 'black'}),
    (lambda aut, e: e.symbol == 97, {'style': 'dashed', 'color': 'black'})
]
n_h = [
    (lambda aut, q: q in aut.final_states, {'color': 'red', 'fillcolor': 'red'}),
    (lambda aut, q: q in aut.initial_states, 
        {'color': 'orange', 'fillcolor': 'orange'}),
]
plotting.plot(con_aut, with_scc=True, node_highlight=n_h, edge_highlight=e_h)
# Out:
# <div style='vertical-align:text-top;display:inline-block;'><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 9.0.0 (0)
#  -->
# <!-- Title: dot Pages: 1 -->
# <svg width="207pt" height="291pt"
#  viewBox="0.00 0.00 207.00 290.80" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 286.8)">
# <title>dot</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-286.8 203,-286.8 203,4 -4,4"/>
# <g id="clust1" class="cluster">
# <title>cluster_0</title>
# <polygon fill="lightgray" stroke="black" points="120,-8 120,-53.6 191,-53.6 191,-8 120,-8"/>
# </g>
# <g id="clust2" class="cluster">
# <title>cluster_1</title>
# <polygon fill="lightgray" stroke="black" points="122,-90.1 122,-127.7 160,-127.7 160,-90.1 122,-90.1"/>
# </g>
# <g id="clust3" class="cluster">
# <title>cluster_2</title>
# <polygon fill="lightgray" stroke="black" points="8,-12 8,-274.8 112,-274.8 112,-12 8,-12"/>
# </g>
# <!-- 4 -->
# <g id="node1" class="node">
# <title>4</title>
# <ellipse fill="red" stroke="red" stroke-width="1.5" cx="143" cy="-30.8" rx="10.8" ry="10.8"/>
# <ellipse fill="none" stroke="red" stroke-width="1.5" cx="143" cy="-30.8" rx="14.8" ry="14.8"/>
# <text text-anchor="middle" x="143" y="-26.52" font-family="Courier,monospace" font-weight="bold" font-size="12.00">4</text>
# </g>
# <!-- 4&#45;&gt;4 -->
# <g id="edge10" class="edge">
# <title>4&#45;&gt;4</title>
# <path fill="none" stroke="black" stroke-width="1.5" d="M156.48,-37.67C166.16,-39.9 175.8,-37.61 175.8,-30.8 175.8,-27.07 172.92,-24.7 168.72,-23.68"/>
# <polygon fill="black" stroke="black" stroke-width="1.5" points="168.67,-20.18 158.75,-23.89 168.82,-27.18 168.67,-20.18"/>
# <text text-anchor="start" x="175.8" y="-25.75" font-family="Times,serif" font-size="14.00">b</text>
# </g>
# <!-- 3 -->
# <g id="node2" class="node">
# <title>3</title>
# <ellipse fill="lightsteelblue" stroke="darkblue" stroke-width="1.5" cx="141" cy="-108.9" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="141" y="-104.62" font-family="Courier,monospace" font-weight="bold" font-size="12.00">3</text>
# </g>
# <!-- 3&#45;&gt;4 -->
# <g id="edge9" class="edge">
# <title>3&#45;&gt;4</title>
# <path fill="none" stroke="black" stroke-width="1.5" stroke-dasharray="5,2" d="M141.27,-97.64C141.53,-87.55 141.95,-71.74 142.31,-58.14"/>
# <polygon fill="black" stroke="black" stroke-width="1.5" points="145.8,-58.4 142.57,-48.31 138.8,-58.22 145.8,-58.4"/>
# <text text-anchor="start" x="142" y="-66.8" font-family="Times,serif" font-size="14.00">a</text>
# </g>
# <!-- q0 -->
# <g id="node3" class="node">
# <title>q0</title>
# </g>
# <!-- 0 -->
# <g id="node4" class="node">
# <title>0</title>
# <ellipse fill="orange" stroke="orange" stroke-width="1.5" cx="69" cy="-183" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="69" y="-178.72" font-family="Courier,monospace" font-weight="bold" font-size="12.00">0</text>
# </g>
# <!-- q0&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>q0&#45;&gt;0</title>
# <path fill="none" stroke="midnightblue" stroke-width="1.5" d="M69,-231.04C69,-223.47 69,-214.43 69,-206.3"/>
# <polygon fill="midnightblue" stroke="midnightblue" stroke-width="1.5" points="72.5,-206.54 69,-196.54 65.5,-206.54 72.5,-206.54"/>
# </g>
# <!-- 0&#45;&gt;3 -->
# <g id="edge4" class="edge">
# <title>0&#45;&gt;3</title>
# <path fill="none" stroke="black" stroke-width="1.5" stroke-dasharray="5,2" d="M77.45,-175.76C84.55,-170.36 94.82,-162.19 103,-154.2 111.46,-145.94 120.11,-136 127.01,-127.63"/>
# <polygon fill="black" stroke="black" stroke-width="1.5" points="129.7,-129.87 133.25,-119.89 124.25,-125.48 129.7,-129.87"/>
# <text text-anchor="start" x="118" y="-140.9" font-family="Times,serif" font-size="14.00">a</text>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="black" stroke-width="1.5" stroke-dasharray="5,2" d="M79.04,-187.52C88.1,-189.71 97.8,-188.21 97.8,-183 97.8,-180.23 95.06,-178.51 91.14,-177.84"/>
# <polygon fill="black" stroke="black" stroke-width="1.5" points="91.1,-174.33 81.3,-178.36 91.48,-181.32 91.1,-174.33"/>
# <text text-anchor="start" x="97.8" y="-177.95" font-family="Times,serif" font-size="14.00">a</text>
# </g>
# <!-- 1 -->
# <g id="node5" class="node">
# <title>1</title>
# <ellipse fill="lightsteelblue" stroke="darkblue" stroke-width="1.5" cx="27" cy="-108.9" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="27" y="-104.62" font-family="Courier,monospace" font-weight="bold" font-size="12.00">1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" stroke-width="1.5" stroke-dasharray="5,2" d="M63.85,-173.16C57.49,-162.24 46.49,-143.36 38.16,-129.06"/>
# <polygon fill="black" stroke="black" stroke-width="1.5" points="41.39,-127.65 33.33,-120.77 35.34,-131.18 41.39,-127.65"/>
# <text text-anchor="start" x="52" y="-140.9" font-family="Times,serif" font-size="14.00">a</text>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g id="edge5" class="edge">
# <title>1&#45;&gt;1</title>
# <path fill="none" stroke="black" stroke-width="1.5" stroke-dasharray="5,2" d="M36.74,-114.52C45.88,-117.43 55.8,-115.56 55.8,-108.9 55.8,-105.26 52.83,-103.05 48.65,-102.27"/>
# <polygon fill="black" stroke="black" stroke-width="1.5" points="48.67,-98.76 39,-103.09 49.26,-105.73 48.67,-98.76"/>
# <text text-anchor="start" x="55.8" y="-103.85" font-family="Times,serif" font-size="14.00">a</text>
# </g>
# <!-- 2 -->
# <g id="node6" class="node">
# <title>2</title>
# <ellipse fill="lightsteelblue" stroke="darkblue" stroke-width="1.5" cx="64" cy="-30.8" rx="10.8" ry="10.8"/>
# <text text-anchor="middle" x="64" y="-26.52" font-family="Courier,monospace" font-weight="bold" font-size="12.00">2</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge6" class="edge">
# <title>1&#45;&gt;2</title>
# <path fill="none" stroke="black" stroke-width="1.5" d="M27.95,-97.94C29.14,-88.66 31.75,-74.62 37.25,-63.6 40.08,-57.93 44.12,-52.4 48.21,-47.59"/>
# <polygon fill="black" stroke="black" stroke-width="1.5" points="50.49,-50.28 54.74,-40.57 45.37,-45.51 50.49,-50.28"/>
# <text text-anchor="start" x="38" y="-66.8" font-family="Times,serif" font-size="14.00">b</text>
# </g>
# <!-- 2&#45;&gt;0 -->
# <g id="edge7" class="edge">
# <title>2&#45;&gt;0</title>
# <path fill="none" stroke="black" stroke-width="1.5" stroke-dasharray="5,2" d="M65.55,-41.67C67.28,-53.24 69.98,-73 71,-90.1 72,-106.78 71.31,-110.99 71,-127.7 70.8,-138.33 70.39,-150.13 69.99,-160.01"/>
# <polygon fill="black" stroke="black" stroke-width="1.5" points="66.51,-159.59 69.58,-169.73 73.5,-159.89 66.51,-159.59"/>
# <text text-anchor="start" x="71" y="-103.85" font-family="Times,serif" font-size="14.00">a</text>
# </g>
# <!-- 2&#45;&gt;1 -->
# <g id="edge8" class="edge">
# <title>2&#45;&gt;1</title>
# <path fill="none" stroke="black" stroke-width="1.5" stroke-dasharray="5,2" d="M59.97,-41.15C55.69,-50.94 48.64,-66.73 42,-80.1 40.64,-82.84 39.16,-85.7 37.68,-88.5"/>
# <polygon fill="black" stroke="black" stroke-width="1.5" points="34.65,-86.76 32.96,-97.22 40.8,-90.09 34.65,-86.76"/>
# <text text-anchor="start" x="50" y="-66.8" font-family="Times,serif" font-size="14.00">a</text>
# </g>
# </g>
# </svg>
# </div>
